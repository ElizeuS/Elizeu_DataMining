# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_dados = pd.read_excel("teste2.xlsx")

# %%
df_dados[(df_dados['BAIRRO DA OCORRENCIA'] == 'NOSSA SRA DA APRESENTAÇÃO') & 
         (df_dados['DIA'] == 'domingo')].groupby(['LOGRADOURO DA OCORRENCIA', 'MÊS']).count()
# Out:
#                                                         TIPO DE MORTE  ANO  \
# LOGRADOURO DA OCORRENCIA                           MÊS
# AV BOA SORTE                                       9                1    1
# AV INDUSTRIAL                                      3                1    1
#                                                    5                1    1
#                                                    12               1    1
# AV INDUSTRIAL Nº 1234                              10               2    2
# AV INDUSTRIAL Nº 18                                10               1    1
# AV MARANGUAPE                                      2                1    1
#                                                    5                1    1
#                                                    9                1    1
# AV PEDRO ALVARES CABRAL                            11               1    1
# AV PRIMAVERA                                       5                1    1
# ...
