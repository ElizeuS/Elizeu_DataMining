# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_dados = pd.read_excel('mortes_dados.xlsx')

# %%
(df_dados.groupby(["PROFISSAO"]).count()).sort_values(by=["ANO"]).head(242)
# Out:
#                                 TIPO DE MORTE  ANO  DATA  HORA  CIDADE  \
# PROFISSAO
# ABATEDOR(A)                                 1    1     1     1       1
# EX PRESIDIARIO                              1    1     1     1       1
# EX-POLICIAL MILITAR                         1    1     1     1       1
# FETO                                        1    1     1     1       1
# FUNCIONARIO PUBLICO                         1    1     1     1       1
# FUNCIONARIO PUBLICO APOSENTADO              1    1     1     1       1
# FUNILEIRO                                   1    1     1     1       1
# GARCONETE                                   1    1     1     1       1
# GARÇOM                                      1    1     1     1       1
# GERENTE ADMINISTRATIVO                      1    1     1     1       1
# GERENTE DE HOTEL                            1    1     1     1       1
# GUARDA DE TRANSITO                          1    1     1     1       1
# ...

# %% [markdown]
# ## Padronizando os dados da tabela integrada

# %%
df_dados = df_dados.replace(['IGNORADO', 'IGNORADA', 'IGNORADO(A)', 'INDEFINIDO', 'INDEFINIDO(A)', 'INDEFINIDA', '#N/D', 'NAO INFORMADO NA GUIA DO DELEGADO', 'NI, NI, NI, NI'
], 'NI')

# %%
df_dados[(df_dados["IDADE"] == "NI") & (df_dados["ESCOLARIDADE"] == "NI") & (df_dados["PROFISSAO"] == "NI")].groupby(['ID']).count()
# Out:
#       TIPO DE MORTE  ANO  DATA  HORA  CIDADE  BAIRRO DA OCORRENCIA  \
# ID
# 0                 1    1     1     1       1                     1
# 13                1    1     1     1       1                     1
# 22                1    1     1     1       1                     1
# 36                1    1     1     1       1                     1
# 54                1    1     1     1       1                     1
# 67                1    1     1     1       1                     1
# 68                1    1     1     1       1                     1
# 70                1    1     1     1       1                     1
# 86                1    1     1     1       1                     1
# 89                1    1     1     1       1                     1
# 109               1    1     1     1       1                     1
# 116               1    1     1     1       1                     1
# 118               1    1     1     1       1                     1
# ...

# %%
df_dados.groupby(["ANO"]).count()
# Out:
#       TIPO DE MORTE  DATA  HORA  CIDADE  BAIRRO DA OCORRENCIA  \
# ANO
# 2012            449   449   449     449                   449
# 2013            577   577   577     577                   577
# 2014            568   568   568     568                   568
# 2015            495   495   495     495                   495
# 2016            546   546   546     546                   546
# 2017            565   565   565     565                   565
#
#       LOGRADOURO DA OCORRENCIA  GENERO  ETNIA  IDADE  PROFISSAO  ESCOLARIDADE  \
# ANO
# 2012                       449     449    449    449        449           449
# 2013                       577     577    577    577        577           577
# 2014                       568     568    568    568        568           568
# 2015                       495     495    495    495        495           495
# 2016                       546     546    546    546        546           546
# ...

# %% [markdown]
# * df_mortes2_att = df_mortes2.replace(['A.S.G'], 'ASG')
# * df_mortes2_att = df_mortes2_att.replace(['SEM PROFISSAO'], 'DESEMPREGADO')
# * df_mortes2_att = df_mortes2_att.replace(['SERVENTE'], 'SERVENTE DE PEDREIRO')

# %%
df_dados.groupby(["INSTRUMENTO UTILIZADO"]).count()
# Out:
#                             TIPO DE MORTE   ANO  DATA  HORA  CIDADE  \
# INSTRUMENTO UTILIZADO
# ACAO CONTUDENTE                         1     1     1     1       1
# ARMA BRANCA                           231   231   231   231     231
# ARMA DE FOGO                         2785  2785  2785  2785    2785
# ARMA DE FOGO / PAULADA                  1     1     1     1       1
# ARMA DE FOGO /ARMA BRANCA               1     1     1     1       1
# ASFIXIA MECANICA PROVOCADA             35    35    35    35      35
# CARBONIZACAO                            7     7     7     7       7
# ELETROPLESSAO                           2     2     2     2       2
# ENFORCAMENTO                            2     2     2     2       2
# ESPANCAMENTO                           64    64    64    64      64
# NAO IDENTIFICADO                       12    12    12    12      12
# NI                                      2     2     2     2       2
# ...

# %%
df_idadeNI = df_dados[(df_dados['IDADE'] == 'NI')]

# %%
df_temIdade = df_dados[(df_dados['IDADE'] != 'NI')]

# %%
df_idadeNI.groupby(['PROFISSAO', 'ESCOLARIDADE'])['IDADE'].count()
# Out:
# PROFISSAO             ESCOLARIDADE
# AJUDANTE DE GESSEIRO  NI                                 1
# ASG                   FUNDAMENTAL                        1
# AUTONOMO(A)           FUNDAMENTAL                        2
# DESEMPREGADO          ENSINO FUNDAMENTAL INCOMPLETO      1
# DESEMPREGADO(A)       NI                                 2
# DESOCUPADO(A)         NI                                 2
# DETENTO               NI                                 1
# DIARISTA              NI                                 1
# ESTUDANTE B           FUNDAMENTAL                        2
# FLANELINHA            FUNDAMENTAL                        1
# GARCOM                MEDIO                              1
# MECANICO(A)           MEDIO                              1
# MENOR SEM OCUPACAO    NI                                 1
# MORADOR DE RUA        NI                                 1
# MOTORISTA             MEDIO                              1
# ...

# %% [markdown]
# #### PEGANDO A IDADE MÉDIA DE ESTUDANTE QUE FAZ O FUNDAMENTAL

# %%
df_temIdade[(df_temIdade['ESCOLARIDADE']=='FUNDAMENTAL') & (df_temIdade['PROFISSAO']=='ESTUDANTE B')]['IDADE'].mean().astype(int)
# Out:
# 16

# %% [markdown]
# ##### DEFINE O FORMATO DA SAIDA COMO INTEIRO   .astype(int)
#  ** Ex a = [2.444].astype(int);
#        a -> 2              **

# %%
df_idadeNI[(df_idadeNI['ESCOLARIDADE'] == 'NI') & (df_idadeNI['PROFISSAO'] == 'NI')].count()
# Out:
# TIPO DE MORTE               163
# ANO                         163
# DATA                        163
# HORA                        163
# CIDADE                      163
# BAIRRO DA OCORRENCIA        163
# LOGRADOURO DA OCORRENCIA    163
# GENERO                      163
# ETNIA                       163
# IDADE                       163
# PROFISSAO                   163
# ESCOLARIDADE                163
# INSTRUMENTO UTILIZADO       163
# ID                          163
# Unnamed: 14                   0
# Unnamed: 15                   1
# dtype: int64
